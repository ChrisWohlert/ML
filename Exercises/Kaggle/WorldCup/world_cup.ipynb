# %%
import os
import pandas
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from datetime import datetime
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from matplotlib import pyplot
from sklearn.metrics import accuracy_score
import random

path = os.path.join(os.getcwd(), "international_matches.csv")
dataset = pandas.read_csv(path)

df = dataset.sort_values('home_team_total_fifa_points')
df.tail()
# Out:
#              date home_team away_team home_team_continent away_team_continent  \
# 20448  2018-07-14   Belgium   England              Europe              Europe
# 20443  2018-07-06    Brazil   Belgium       South America              Europe
# 20437  2018-07-02    Brazil    Mexico       South America       North America
# 20446  2018-07-10    France   Belgium              Europe              Europe
# 20449  2018-07-15    France   Croatia              Europe              Europe
#
#        home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 20448                    5                    7                         2124
# 20443                    4                    5                         2160
# 20437                    4                   10                         2160
# 20446                    2                    5                         2164
# 20449                    2                   12                         2164
#
#        away_team_total_fifa_points  home_team_score  ...  shoot_out  \
# 20448                         2099                2  ...         No
# 20443                         2124                1  ...         No
# 20437                         2041                2  ...         No
# 20446                         2124                1  ...         No
# 20449                         2036                4  ...         No
#
#       home_team_result home_team_goalkeeper_score away_team_goalkeeper_score  \
# 20448              Win                       89.0                       82.0
# 20443             Lose                       83.0                       89.0
# 20437              Win                       83.0                       79.0
# 20446              Win                       88.0                       89.0
# 20449              Win                       88.0                       85.0
#
#        home_team_mean_defense_score home_team_mean_offense_score  \
# 20448                          83.5                         87.3
# 20443                          86.8                         87.0
# 20437                          86.8                         87.0
# 20446                          84.0                         86.3
# 20449                          84.0                         86.3
#
#       home_team_mean_midfield_score  away_team_mean_defense_score  \
# 20448                          85.8                          82.8
# 20443                          83.8                          83.5
# 20437                          83.8                          77.8
# 20446                          86.2                          83.5
# 20449                          86.2                          80.8
#
#        away_team_mean_offense_score  away_team_mean_midfield_score
# 20448                          83.3                           82.8
# 20443                          87.3                           85.8
# 20437                          81.0                           80.0
# 20446                          87.3                           85.8
# 20449                          79.3                           85.8
#
# [5 rows x 25 columns]
